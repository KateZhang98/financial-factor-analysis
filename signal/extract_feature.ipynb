# %%
import datetime
import time
import sys
sys.path.append(r'/home/hengtian/lucy/factor-analyzer-v4/')
import pymysql
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import multiprocessing
import os
import queue
import tqdm
import imp
sys.path.append(os.path.abspath('/home/hengtian/kate/'))
import get_factor_tools as gft
imp.reload(gft)
# Out:
# <module 'get_factor_tools' from '/home/hengtian/kate/get_factor_tools.py'>

# %%
#一致预期变动y1
npc_y1 = gft.get_stock_factor('npc_y1',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#一致预期变动y2
npc_y2 = gft.get_stock_factor('npc_y2',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#投资评级变动
rate = gft.get_stock_factor('rating_change_factor',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#护城河因子
moat = gft.get_stock_factor('moat_grade',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#未来增速
np_g1 = gft.get_stock_factor('netProfit_g1',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#长研报
lr = gft.get_stock_factor('lr',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#当前单季成长
growth_cur = gft.get_stock_factor('netProfit_g_mrq',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))

# %%
#前一期单季成长因子值
q1 = gft.get_stock_factor('netProfit_q_mrq_1',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))
q5 = gft.get_stock_factor('netProfit_q_mrq_5',start_date =datetime.date(2013, 1, 1),end_date = datetime.date(2021, 7, 13))
growth_prev = q1/q5.abs()-1

# %%
# npc_y1.to_csv('npc_y1.csv')
# npc_y2.to_csv('npc_y2.csv')
# rate.to_csv('rate.csv')
# moat.to_csv('moat.csv')
# np_g1.to_csv('np_g1.csv')
# lr.to_csv('lr.csv')
# growth_cur.to_csv('growth_cur.csv')
growth_prev.to_csv('growth_prev.csv')

# %%
growth_cur

# %%
growth_prev =(q1-q5)/q5.abs()

# %%
npc_y1
# Out:
#             000001.XSHE  000002.XSHE  000003.XSHE  000004.XSHE  000005.XSHE  \
# 2013-01-01      -0.9154       2.2317          NaN          NaN          NaN
# 2013-01-02      -0.8934       2.1781          NaN          NaN          NaN
# 2013-01-03      -0.8720       2.1258          NaN          NaN          NaN
# 2013-01-04      -0.8510       2.0748          NaN          NaN          NaN
# 2013-01-05      -0.8306       2.0250          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2021-07-09       1.1392      -0.1862          NaN          NaN          NaN
# 2021-07-10       1.1118      -0.1872          NaN          NaN          NaN
# 2021-07-11       1.0851      -0.1827          NaN          NaN          NaN
# 2021-07-12       1.0591      -0.1783          NaN          NaN          NaN
# 2021-07-13       1.0337      -0.1740          NaN          NaN          NaN
#
# ...

# %%
npc_y1 = pd.read_csv('/home/hengtian/kate/signal/data/npc_y1.csv',index_col=0)

# %%
npc_rank = npc_y1.rank(axis=1,pct=True)

# %%
npc_rank
# Out:
#             000001.XSHE  000002.XSHE  000003.XSHE  000004.XSHE  000005.XSHE  \
# 2013-01-01     0.107678     0.979869          NaN          NaN          NaN
# 2013-01-02     0.107678     0.979869          NaN          NaN          NaN
# 2013-01-03     0.107678     0.979869          NaN          NaN          NaN
# 2013-01-04     0.110955     0.978464          NaN          NaN          NaN
# 2013-01-05     0.110019     0.977996          NaN          NaN          NaN
# ...                 ...          ...          ...          ...          ...
# 2021-07-09     0.883721     0.117336          NaN          NaN          NaN
# 2021-07-10     0.885428     0.114044          NaN          NaN          NaN
# 2021-07-11     0.880676     0.114044          NaN          NaN          NaN
# 2021-07-12     0.869519     0.122029          NaN          NaN          NaN
# 2021-07-13     0.861067     0.128368          NaN          NaN          NaN
#
# ...

# %%
npc_rank.to_csv('npc_rank.csv')

# %%
npc_y2 = pd.read_csv('/home/hengtian/kate/signal/data/npc_y2.csv',index_col=0)

# %%
npcy2_rank = npc_y2.rank(axis=1,pct=True)
npcy2_rank.to_csv('npcy2_rank.csv')

# %%
rate = pd.read_csv('/home/hengtian/kate/signal/data/rate.csv',index_col=0)

# %%
rate_rank = rate.rank(axis=1,pct=True)
rate_rank.to_csv('rate_rank.csv')

# %%
moat = pd.read_csv('/home/hengtian/kate/signal/data/moat.csv',index_col=0)

# %%
moat_rank = moat.rank(axis=1,pct=True)
moat_rank.to_csv('moat_rank.csv')

# %%
np_g1=pd.read_csv('/home/hengtian/kate/signal/data/np_g1.csv',index_col=0)

# %%
np_g1_rank = np_g1.rank(axis=1,pct=True)
np_g1_rank.to_csv('np_g1_rank.csv')

# %%
lr=pd.read_csv('/home/hengtian/kate/signal/data/lr.csv',index_col=0)

# %%
lr_rank = lr.rank(axis=1,pct=True)
lr_rank.to_csv('lr_rank.csv')

# %%
growth_cur=pd.read_csv('/home/hengtian/kate/signal/data/growth_cur.csv',index_col=0)

# %%
growth_cur_rank = growth_cur.rank(axis=1,pct=True)
growth_cur_rank.to_csv('growth_cur_rank.csv')

# %%
growth_prev=pd.read_csv('/home/hengtian/kate/signal/data/growth_prev.csv',index_col=0)

# %%
growth_prev_rank = growth_prev.rank(axis=1,pct=True)
growth_prev_rank.to_csv('growth_prev_rank.csv')
